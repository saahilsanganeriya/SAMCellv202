# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img_path = '../../datasets/train-05/imgs.npy'
ann_path = '../../datasets/train-05/anns.npy'
# weights_path = 'output/weights.npy'

# %%
#load images and annotations
imgs = np.load(img_path)
anns = np.load(ann_path)[:,0,:,:]
# weights = np.load(weights_path)

print(f'imgs shape: {imgs.shape}, anns shape: {anns.shape}')
# Out:
# imgs shape: (162, 520, 704, 3), anns shape: (162, 520, 704)

# %%
random_index = np.random.randint(0, imgs.shape[0])

#show image and annotations
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
ax[0].imshow(imgs[random_index])
ax[1].imshow(anns[random_index])
plt.show()

# %%
#show a random weight map
# random_index = np.random.randint(0, weights.shape[0])
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
# ax.imshow(weights[random_index])
plt.show()
